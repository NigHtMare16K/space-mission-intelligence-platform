# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Data Analysis/Space Mission Analysis/Dataset/Space_Missions_Dataset.csv')

# %%
df['Launch_Year'] = df['Launch_Date'].str.split("-").str[0]

# %%
df['Mission_Name'].value_counts()
# Out:
# Mission_Name
# CRS-10                          2
# Crew-7                          2
# Mars Express                    2
# CRS-30                          2
# CRS-25                          2
#                                ..
# CNES Sun/Solar Mission 3532     1
# NASA Deep Space Mission 3533    1
# CNSA Sun/Solar Mission 3534     1
# DLR Mars Mission 3535           1
# CNSA Sun/Solar Mission 10500    1
# Name: count, Length: 10477, dtype: int64

# %%
df1 = df[df['Mission_Name'] == 'CRS-10']

# %%
df1
# Out:
#     Mission_ID Mission_Name  Agency Country_Region Agency_Type Program_Type  \
# 115   NA-00116       CRS-10    NASA            USA  Government    Telescope
# 837   SP-00838       CRS-10  SpaceX            USA     Private    Satellite
#
#     Mission_Category      Sub_Category Launch_Date    End_Date  ...  \
# 115  Technology Demo    Debris Removal  1969-05-04  1974-10-04  ...
# 837         SmallSat  IoT Connectivity  2002-09-29  2005-05-26  ...
#
#          Destination                                  Objective  \
# 115  Technology Demo  Interplanetary navigation technology test
# 837         SmallSat           Heliosphere boundary exploration
#
#                                    Key_Achievement Cost_USD_Million  \
# 115  First images returned from target destination           2232.3
# 837           Demonstrated reusable rocket landing           5093.3
#
#     Partner_Agencies Data_Returned Failure_Reason  \
# 115              NaN       Partial            NaN
# 837             NASA           Yes            NaN
#
#                         Mission_Outcome_Detail  \
# 115  Achieved orbit insertion on first attempt
# 837           Broke distance record for agency
#
#                               Reference_URL Launch_Year
# 115     https://www.nasa.gov/mission/crs-10        1969
# 837  https://www.spacex.com/missions/crs-10        2002
#
# [2 rows x 27 columns]

# %%
df1['Destination'][:1].value_counts().index[:1]
# Out:
# Index(['Technology Demo'], dtype='object', name='Destination')

# %%
df1.columns
# Out:
# Index(['Mission_ID', 'Mission_Name', 'Agency', 'Country_Region', 'Agency_Type',
#        'Program_Type', 'Mission_Category', 'Sub_Category', 'Launch_Date',
#        'End_Date', 'Duration', 'Launch_Vehicle', 'Launch_Site', 'Status',
#        'Mission_Phase', 'Crew_Type', 'Crew_Members', 'Destination',
#        'Objective', 'Key_Achievement', 'Cost_USD_Million', 'Partner_Agencies',
#        'Data_Returned', 'Failure_Reason', 'Mission_Outcome_Detail',
#        'Reference_URL', 'Launch_Year'],
#       dtype='object')

# %%
def MissionComp(m1,m2):
    df2 = df[df['Mission_Name'] == m1].iloc[0]
    df3 = df[df['Mission_Name'] == m2].iloc[0]

    l1 = df2['Launch_Year']
    l2 = df3['Launch_Year']

    d1= df2['Destination']
    d2= df3['Destination']

    a1 = df2['Agency']
    a2 = df3['Agency']

    b1 = df2['Cost_USD_Million']
    b2 = df3['Cost_USD_Million']

    t1 = df2['Duration']
    t2 = df3['Duration']

    agency_type1 = df2['Agency_Type']
    agency_type2 = df3['Agency_Type']

    launch1 = df2['Launch_Vehicle']
    launch2 = df3['Launch_Vehicle']

    s1 = df2['Status']
    s2 = df3['Status']

    mission_cat1 = df2['Mission_Category']
    mission_cat2 = df3['Mission_Category']

    ach1 = df2['Key_Achievement']
    ach2 = df3['Key_Achievement']

    obj1 = df2['Objective']
    obj2 = df3['Objective']

    return {"mission_1":{
        'mission_name': m1,
        'Launch Vehicle': launch1,
        'Agency Type': agency_type1,
        'Mission Category': mission_cat1,
        'Status': s1,
        'Duration': t1,
        'Agency': a1,
        'Launch Year': l1,
        'Destination': d1,
        'Budget': b1,
        'Achievement': ach1,
        'Objective': obj1
    },
    "mission_2":
    {
        'mission_name': m2,
        'Launch Vehicle': launch2,
        'Agency Type': agency_type2,
        'Mission Category': mission_cat2,
        'Status': s2,
        'Duration': t2,
        'Agency': a2,
        'Launch Year': l2,
        'Destination': d2,
        'Budget': b2,
        'Achievement': ach2,
        'Objective': obj2
    }
    }

# %%
df['Mission_Name'].value_counts()
# Out:
# Mission_Name
# CRS-10                          2
# Crew-7                          2
# Mars Express                    2
# CRS-30                          2
# CRS-25                          2
#                                ..
# CNES Sun/Solar Mission 3532     1
# NASA Deep Space Mission 3533    1
# CNSA Sun/Solar Mission 3534     1
# DLR Mars Mission 3535           1
# CNSA Sun/Solar Mission 10500    1
# Name: count, Length: 10477, dtype: int64

# %%
m1 = 'CRS-30'
m2 = 'Mars Express'
a = MissionComp(m1,m2)
print(a)
# Out:
# {'mission_1': {'mission_name': 'CRS-30', 'Launch Vehicle': 'Pegasus', 'Agency Type': 'Government', 'Mission Category': 'Earth Observation', 'Status': 'Failed', 'Duration': '11.4 years', 'Agency': 'NASA', 'Launch Year': '1968', 'Destination': 'Earth Observation', 'Budget': 1383.4, 'Achievement': 'Software error during critical maneuver', 'Objective': 'Human lunar landing mission support'}, 'mission_2': {'mission_name': 'Mars Express', 'Launch Vehicle': 'Falcon 9', 'Agency Type': 'Government', 'Mission Category': 'Moon', 'Status': 'Success', 'Duration': '359 days', 'Agency': 'NASA', 'Launch Year': '2015', 'Destination': 'Moon', 'Budget': 12495.7, 'Achievement': 'Confirmed presence of subsurface water', 'Objective': 'Jupiter moon subsurface ocean investigation'}}

# %%
from dotenv import load_dotenv
load_dotenv()
from pydantic import BaseModel

# %%
class MissionComparison(BaseModel):
    historical_impact: str
    scientific_value: str
    technological_innovation: str
    cost_efficiency: str
    mission_success: str
    overall_winner: str
    summary: str

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')
structured_llm = llm.with_structured_output(MissionComparison)

# %%
m1 = 'CRS-30'
m2 = 'Mars Express'
a = MissionComp(m1,m2)

prompt = f"""
You are an expert space mission analyst and educator.

Compare the following two space missions primarily using the provided mission data.

Mission 1:
{a['mission_1']}

Mission 2:
{a['mission_2']}

Your task:

1. Determine which mission had greater historical impact.
2. Determine which mission contributed more scientifically.
3. Determine which mission demonstrated greater technological innovation.
4. Determine which mission was more cost efficient.
5. Determine which mission was more successful overall.

Guidelines:
- Prioritize the provided mission information.
- Use general space knowledge only when absolutely necessary.
- Never invent missing facts.
- If a category cannot be determined fairly, return "Tie".
- Explain decisions concisely.
- Write for students and space enthusiasts.

For similarities:
- Include common objectives, agencies, destinations, technologies, or mission goals.

For differences:
- Include launch year, destination, agency, cost, status, duration, or achievements.

The overall winner should consider:
- Historical significance
- Scientific value
- Mission success
- Technological contribution

The summary should be 150–250 words explaining the comparison and final verdict.
"""

# %%
response = llm.invoke(prompt)

print(response.content)
# Out:
# Let's compare these two fascinating missions, "CRS-30" and "Mars Express," based strictly on the provided data, acknowledging some intriguing contradictions within the information.
#
# **Similarities:**
# Both missions were managed by the 'Government' agency 'NASA' and had specific scientific or operational 'Objectives'.
#
# **Differences:**
# They differ significantly in their 'Launch Year' (1968 vs. 2015), 'Status' ('Failed' vs. 'Success'), 'Duration' (11.4 years vs. 359 days), 'Budget' (1383.4 vs. 12495.7), and 'Launch Vehicle' ('Pegasus' vs. 'Falcon 9'). Most notably, their 'Achievement' and primary 'Objective' are vastly different, with Mission 1 failing due to a software error and Mission 2 successfully confirming subsurface water. There are also notable contradictions in the provided data for Mission 1's destination/category versus objective, and for Mission 2's name, category, destination, objective, and achievement.
#
# ---
#
# Here's how they stack up:
#
# 1.  **Greater Historical Impact:**
#     **Mission 1 (CRS-30)**. Despite its failure, its 1968 launch year and objective to support a 'Human lunar landing mission' place it squarely in the context of the Apollo era, a period of unparalleled historical significance for humanity. Mission 2, while successful, lacks this direct tie to such a monumental historical event.
#
# 2.  **More Scientifically Contributive:**
#     **Mission 2 (Mars Express)**. Its 'Success' status and the explicit 'Achievement' of 'Confirmed presence of subsurface water' represent a clear and significant scientific discovery. Mission 1's 'Failed' status due to a 'Software error' means it made no scientific contribution.
#
# 3.  **Greater Technological Innovation:**
#     **Mission 2 (Mars Express)**. Its 'Success' in achieving a complex scientific goal ('Confirmed presence of subsurface water') demonstrates the effective application of advanced technology. While Mission 1's use of a 'Pegasus' vehicle in 1968 (despite historical discrepancies in its first flight) would be innovative, its 'Failure' due to a 'Software error' indicates a critical lack of demonstrated innovation in its core mission systems. Mission 2's use of the 'Falcon 9' in 2015 also aligns with a period of significant launch vehicle innovation.
#
# 4.  **More Cost Efficient:**
#     **Mission 2 (Mars Express)**. Although significantly more expensive (12495.7 vs. 1383.4), Mission 2 was a 'Success' and delivered a major scientific 'Achievement'. Mission 1, despite its lower budget, 'Failed' and delivered no return on investment, making it less cost-efficient.
#
# 5.  **More Successful Overall:**
#     **Mission 2 (Mars Express)**. With a 'Success' status and a significant scientific 'Achievement', Mission 2 clearly achieved its goals, whereas Mission 1 explicitly 'Failed'.
#
# ---
#
# **Overall Winner and Summary:**
#
# Comparing "CRS-30" and "Mars Express" reveals two vastly different outcomes. "CRS-30," a NASA mission from 1968, aimed to support human lunar landings. However, it ultimately 'Failed' due to a software error, resulting in no scientific or operational achievement. Its intended role in the historic Apollo era gives it potential historical weight, but its failure means this potential was unrealized.
#
# In stark contrast, "Mars Express," a NASA mission from 2015, achieved 'Success'. Despite contradictions in the provided data regarding its destination (listed as 'Moon') and objective (listed as 'Jupiter moon subsurface ocean investigation'), its 'Achievement' of 'Confirmed presence of subsurface water' is a significant scientific breakthrough. This mission demonstrated greater technological innovation through its successful execution and delivered tangible scientific value, even if at a higher budget.
#
# While "CRS-30" holds a unique historical context due to its launch year and objective, "Mars Express" unequivocally outperforms it in scientific contribution, technological demonstration, cost-efficiency, and overall mission success. Therefore, **Mars Express** is the clear overall winner, delivering substantial scientific return on its investment.
